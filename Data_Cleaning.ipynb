# %%
import pandas as pd
import pickle
import calendar
import os
from datetime import datetime

# %% [markdown]
# #### Agriculture DataFrames

# %%
ag_maj_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/agriculture/majority.pkl")

# %%
ag_maj_df["Party"] = "Republican"
ag_maj_df["Committee"] = "Agriculture"
ag_maj_df["Label"] = "Agriculture, Republican"

# %%
def get_date1(date_str):
    arr = date_str.split(".")
    rel_year = 2000 + int(arr[2])
    return datetime(year=rel_year, month=int(arr[0]), day=int(arr[1]))

def get_year(date_obj):
    return date_obj.year

def get_month(date_obj):
    return date_obj.month

def get_day(date_obj):
    return date_obj.day

# %%
ag_maj_df["Date"] = ag_maj_df.apply(lambda row: get_date1(row["Date"]), axis=1)

# %%
ag_maj_df["Year"] = ag_maj_df.apply(lambda row: get_year(row["Date"]), axis=1)
ag_maj_df["Month"] = ag_maj_df.apply(lambda row: get_month(row["Date"]), axis=1)
ag_maj_df["Day"] = ag_maj_df.apply(lambda row: get_day(row["Date"]), axis=1)

# %%
ag_min_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/agriculture/minority.pkl")

# %%
def adjust_min_df(df, party, committee):
    df["Date"] = df.apply(lambda row: get_date1(row["Date"]), axis=1) 
    df["Year"] = df.apply(lambda row: get_year(row["Date"]), axis=1)
    df["Month"] = df.apply(lambda row: get_month(row["Date"]), axis=1)
    df["Day"] = df.apply(lambda row: get_day(row["Date"]), axis=1)
    df["Party"] = party
    df["Committee"] = committee
    df["Label"] = party + ", " + committee
    return df

ag_min_df = adjust_min_df(ag_min_df, "Democratic", "Agriculture")

# %%
with open("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/agriculture/republican.pkl", "wb") as picklefile:
    pickle.dump(ag_maj_df, picklefile)

# %% [markdown]
# #### Appropriations DataFrame

# %%
apr_maj_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/appropriations/majority.pkl")
apr_min_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/appropriations/minority.pkl")

# %% [markdown]
# #### Banking

# %%
bank_dem = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/banking/democratic.pkl")
bank_gop = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/banking/republican.pkl")

# %%
bank_dem
# Out:
#                    Date                                              Title  \
# 0     November 13, 2017  Brown Opposes Legislation to Roll Back Dodd-Fr...
# 1      November 1, 2017  Brown Opening Statement at Banking Committee H...
# 2      October 24, 2017  Brown Opening Statement at Banking Committee H...
# 3      October 17, 2017  Brown Opening Statement at Banking Committee H...
# 4       October 4, 2017  Brown Opening Statement at Banking Committee H...
# 5       October 3, 2017  Brown Opening Statement at Banking Committee H...
# 6    September 28, 2017  Brown Opening Statement at Banking Committee H...
# 7    September 26, 2017  Brown Opening Statement at Banking Committee H...
# 8    September 14, 2017  Brown Opening Statement at Banking Committee H...
# 9    September 12, 2017  Brown Opening Statement at Banking Committee H...
# 10   September 11, 2017  Following Brown's Urging, Equifax Removes Forc...
# ...

# %% [markdown]
# #### Budget Committee

# %%
maj_budget = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/budget/chairman.pkl")
maj_budget.iloc[474]
# Out:
# Date
# Title
# Release
# Name: 474, dtype: object

# %% [markdown]
# #### Commerce Committees

# %%
commerce_dem = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/commerce/democratic_temp.pkl")
commerce_dem.iloc[205]
# Out:
# Date                                        December 1, 2015
# Title      Thune and Nelson Statements on Five-Year Surfa...
# Release    Washington, D.C. – U.S. Sens. John Thune (R-S....
# Name: 205, dtype: object

# %% [markdown]
# #### Finance Committee

# %%
fin_maj_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/finance/majority.pkl")
fin_min_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/finance/minority.pkl")

# %%
fin_min_df
# Out:
#                  Date                                              Title  \
# 0    NOVEMBER 20,2017  Wyden Statement on USTR Releasing Updated NAFT...
# 1    NOVEMBER 16,2017  Wyden Statement on Finance Committee Passage o...
# 2    NOVEMBER 16,2017  Wyden Statement at Finance Committee Markup on...
# 3    NOVEMBER 15,2017  Wyden Statement on Inclusion of Individual Man...
# 4    NOVEMBER 15,2017  Wyden Statement on New Senate Republican Tax Bill
# 5    NOVEMBER 14,2017  Wyden Remarks on Finance Committee Delay in Co...
# 6    NOVEMBER 13,2017  Wyden Statement at Finance Committee Markup on...
# 7    NOVEMBER 13,2017  Wyden Statement on Alex Azar Nomination to Lea...
# 8    NOVEMBER 12,2017  Wyden Statement on New Asia-Pacific Trade Anno...
# 9    NOVEMBER 07,2017  Wyden Remarks at Tax Policy Center on House Re...
# 10   NOVEMBER 07,2017  Wyden Slams Trump Administration Action to Wea...
# 11   NOVEMBER 02,2017                    Wyden Remarks on House Tax Bill
# ...

# %% [markdown]
# #### Foreign Relations

# %%
maj_fr_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/foreign_relations/chairman.pkl")
min_fr_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/foreign_relations/ranking_member.pkl")

# %%
maj_fr_df
# Out:
#                                Date  \
# 0        Tuesday, November 14, 2017
# 1        Tuesday, November 14, 2017
# 2          Monday, October 30, 2017
# 3        Thursday, October 26, 2017
# 4        Thursday, October 19, 2017
# 5          Friday, October 13, 2017
# 6         Thursday, October 5, 2017
# 7          Tuesday, October 3, 2017
# 8      Thursday, September 21, 2017
# 9     Wednesday, September 20, 2017
# 10      Tuesday, September 19, 2017
# 11      Tuesday, September 19, 2017
# 12      Tuesday, September 19, 2017
# 13      Tuesday, September 19, 2017
# 14     Thursday, September 14, 2017
# 15     Thursday, September 14, 2017
# 16      Tuesday, September 12, 2017
# 17     Wednesday, September 6, 2017
# 18        Sunday, September 3, 2017
# 19        Thursday, August 31, 2017
# 20          Monday, August 28, 2017
# 21          Friday, August 25, 2017
# 22          Monday, August 21, 2017
# 23         Thursday, August 3, 2017
# 24         Thursday, August 3, 2017
# ...

# %% [markdown]
# #### HELP Committee

# %%
help_maj_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/help/majority.pkl")
help_min_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/help/minority.pkl")
help_min_df["Date"] = help_min_df.apply(lambda row: get_date1(row["Date"]), axis=1)
help_maj_df["Date"] = help_maj_df.apply(lambda row: get_date1(row["Date"]), axis=1)

# %%
#help_min_df["Date"] = help_min_df.apply(lambda row: get_date1(row["Date"]), axis=1)
test = datetime(year=2009, month=1, day=3)

# %%
help_maj_df
# Out:
#            Date                                              Title  \
# 0    2017-11-16  Alexander, Burr: Senate Unanimously Passes Leg...
# 1    2017-11-16  Alexander Statement on FDA Regenerative Medici...
# 2    2017-11-16  Alexander Meets with HHS Secretary Nominee Ale...
# 3    2017-11-15  HELP Committee Holds Hearing on 4 Well-Qualifi...
# 4    2017-11-15  Alexander: Surgeon General Focus on Wellness C...
# 5    2017-11-14  Alexander: Gene Editing Technology, When Used ...
# 6    2017-11-13  Alexander Statement on Selection of Alex Azar ...
# 7    2017-11-08  Walden, Alexander, and Burr Request Bicameral ...
# 8    2017-11-08  Alexander: New General Counsel Has Opportunity...
# 9    2017-11-07  Alexander: House Passes Bipartisan Legislation...
# 10   2017-11-03  Alexander: Senate Should Act Quickly to Contin...
# 11   2017-11-03  Alexander on Senate Confirmation of Kyle Forts...
# 12   2017-11-02  Thune, Senate Health IT Working Group Members ...
# ...

# %% [markdown]
# #### Small Business Committee

# %%
maj_sb_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/small_business/majority.pkl")
min_sb_df = pd.read_pickle("/Users/danielgilberg/data_science/metis/nlp_partisanship/data/small_business/minority.pkl")

# %%
# Out:
#                    Date                                              Title  \
# 0     November 20, 2017  Senate Small Business Committee Democrats Rele...
# 1     November 14, 2017  Senate Passes Risch, Shaheen Bipartisan Resolu...
# 2      October 31, 2017  Senate Passes Risch, Shaheen Bipartisan Resolu...
# 3      October 26, 2017      Shaheen Statement on Women’s Entrepreneurship
# 4      October 17, 2017  Shaheen Statement on Trump Nominee to be SBA I...
# 5       October 3, 2017  Shaheen Statement on Trump Nominee to Lead SBA...
# 6    September 27, 2017  Shaheen Statement on Small Business Hurricane ...
# 7    September 27, 2017  Shaheen, Velázquez to Equifax: Provide Assista...
# 8    September 20, 2017  Shaheen to Wells Fargo: Did Fraudulent Practic...
# 9    September 18, 2017  Small Business Priorities Included in National...
# 10   September 14, 2017  Shaheen: New Funds to Help New Hampshire Small...
# ...

# %% [markdown]
# ### Adjusting DataFrames

# %%
def get_date2(date_str):
    date_arr = date_str.split(",")
    year = int(date_arr[1])
    month_name = date_arr[0].split(" ")[0].title()
    day = int(date_arr[0].split(" ")[1])
    months = list()
    for num in range(1,13):
        months.append(calendar.month_name[num])
    months_dict = dict(zip(months, range(1,13)))
    month = months_dict[month_name]
    return datetime(year=year, month=month, day=day)
    
get_date2("March 26, 2017")
# Out:
# datetime.datetime(2017, 3, 26, 0, 0)

# %%
def get_date3(date_str): # for when the day of the week is in the name
    date_arr = date_str.split(", ")[1:]
    #print(date_arr)
    year = int(date_arr[1])
    month_name = date_arr[0].split(" ")[0].title()
    day = int(date_arr[0].split(" ")[1])
    months = list()
    for num in range(1,13):
        months.append(calendar.month_name[num])
    months_dict = dict(zip(months, range(1,13)))
    month = months_dict[month_name]
    return datetime(year=year, month=month, day=day)

get_date3("Monday, January 5, 2009")
# Out:
# datetime.datetime(2009, 1, 5, 0, 0)

# %%
def adjust_df1(group, committee, party):
    committee = committee.lower()
    party = party.lower()
    group = group.lower()
    file_path = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, group)
    df = pd.read_pickle(file_path)
    df = df[df["Date"]!= ""]
    df["Date"] = df.apply(lambda row: get_date1(row["Date"]), axis=1) 
    df["Year"] = df.apply(lambda row: get_year(row["Date"]), axis=1)
    df["Month"] = df.apply(lambda row: get_month(row["Date"]), axis=1)
    df["Day"] = df.apply(lambda row: get_day(row["Date"]), axis=1)
    df["Party"] = party.title()
    df["Committee"] = committee.title()
    df["Label"] = party.title() + ", " + committee.title()
    dest_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, party)
    with open(dest_file, "wb") as picklefile:
        pickle.dump(df, picklefile)
    return df

# %%
def adjust_df2(party, committee):
    committee = committee.lower()
    party = party.lower()
    file_path = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, party)
    df = pd.read_pickle(file_path)
    df = df[df["Date"]!= "" & df["Release"] != ""]
    
    df["Date"] = df.apply(lambda row: get_date2(row["Date"]), axis=1)
    df["Year"] = df.apply(lambda row: get_year(row["Date"]), axis=1)
    df["Month"] = df.apply(lambda row: get_month(row["Date"]), axis=1)
    df["Day"] = df.apply(lambda row: get_day(row["Date"]), axis=1)
    df["Party"] = party.title()
    df["Committee"] = committee.title()
    df["Label"] = party.title() + ", " + committee.title()
    dest_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, party)
    with open(dest_file, "wb") as picklefile:
        pickle.dump(df, picklefile)
    return df

# %%
def adjust_df3(party, committee):
    committee = committee.lower()
    party = party.lower()
    temp_party = party + "_temp"
    file_path = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, temp_party)
    df = pd.read_pickle(file_path)
    df = df[df["Date"]!= ""]
    df = df[df["Release"] != ""]
    #print(len(df.iloc[204]["Release"]))
    df["Date"] = df.apply(lambda row: get_date2(row["Date"]), axis=1)
    df["Year"] = df.apply(lambda row: get_year(row["Date"]), axis=1)
    df["Month"] = df.apply(lambda row: get_month(row["Date"]), axis=1)
    df["Day"] = df.apply(lambda row: get_day(row["Date"]), axis=1)
    df["Party"] = party.title()
    df["Committee"] = committee.title()
    df["Label"] = party.title() + ", " + committee.title()
    dest_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, party)
    with open(dest_file, "wb") as picklefile:
        pickle.dump(df, picklefile)
    return df

# %%
def adjust_df4(committee):
    maj_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/majority.pkl".format(committee)
    min_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/minority.pkl".format(committee)
    maj_df = pd.read_pickle(maj_file)
    min_df = pd.read_pickle(min_file)
    maj_df["Date"] = maj_df.apply(lambda row: get_date2(row["Date"]), axis=1)
    min_df["Date"] = min_df.apply(lambda row: get_date2(row["Date"]), axis=1)
    turnover_date = datetime(year=2015, month=1, day=3)
    dem_maj_df = maj_df[maj_df.Date < turnover_date]
    dem_min_df = min_df[min_df.Date >= turnover_date]
    rep_maj_df = maj_df[maj_df.Date >= turnover_date]
    rep_min_df = min_df[min_df.Date < turnover_date]
    rep_arr = [rep_maj_df, rep_min_df]
    dem_arr = [dem_min_df, dem_maj_df]
    rep_df = pd.concat(rep_arr)
    dem_df = pd.concat(dem_arr)
    rep_df["Party"] = "Republican"
    rep_df["Committee"] = committee.replace("_", " ").title()
    rep_df["Label"] = "Republican, " + committee.replace("_", " ").title()
    dem_df["Party"] = "Democratic"
    dem_df["Committee"] = committee.replace("_", " ").title()
    dem_df["Label"] = "Democratic, " + committee.replace("_", " ").title()
    dem_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/democratic.pkl".format(committee)
    with open(dem_file, "wb") as picklefile:
        pickle.dump(dem_df, picklefile)
    rep_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/republican.pkl".format(committee)
    with open(rep_file, "wb") as picklefile:
        pickle.dump(rep_df, picklefile)
    return rep_df

# %%
def adjust_df5(committee):
    committee = committee.replace(" ", "_").lower()
    maj_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/chairman.pkl".format(committee)
    min_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/ranking_member.pkl".format(committee)
    print(maj_file)
    maj_df = pd.read_pickle(maj_file)
    min_df = pd.read_pickle(min_file)
    maj_df = maj_df[maj_df["Date"]!= ""]
    min_df = min_df[min_df["Release"] != ""]
    maj_df["Date"] = maj_df.apply(lambda row: get_date3(row["Date"]), axis=1)
    min_df["Date"] = min_df.apply(lambda row: get_date3(row["Date"]), axis=1)
    turnover_date = datetime(year=2015, month=1, day=3)
    dem_maj_df = maj_df[maj_df.Date < turnover_date]
    dem_min_df = min_df[min_df.Date >= turnover_date]
    rep_maj_df = maj_df[maj_df.Date >= turnover_date]
    rep_min_df = min_df[min_df.Date < turnover_date]
    rep_arr = [rep_maj_df, rep_min_df]
    dem_arr = [dem_min_df, dem_maj_df]
    rep_df = pd.concat(rep_arr)
    dem_df = pd.concat(dem_arr)
    rep_df["Party"] = "Republican"
    rep_df["Committee"] = committee.replace("_", " ").title()
    rep_df["Label"] = "Republican, " + committee.replace("_", " ").title()
    dem_df["Party"] = "Democratic"
    dem_df["Committee"] = committee.replace("_", " ").title()
    dem_df["Label"] = "Democratic, " + committee.replace("_", " ").title()
    dem_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/democratic.pkl".format(committee)
    with open(dem_file, "wb") as picklefile:
        pickle.dump(dem_df, picklefile)
    rep_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/republican.pkl".format(committee)
    with open(rep_file, "wb") as picklefile:
        pickle.dump(rep_df, picklefile)
    return rep_df

# %%
def adjust_df6(committee):
    committee = committee.lower()
    maj_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/majority.pkl".format(committee)
    min_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/minority.pkl".format(committee)
    maj_df = pd.read_pickle(maj_file)
    min_df = pd.read_pickle(min_file)
    maj_df["Date"] = maj_df.apply(lambda row: get_date1(row["Date"]), axis=1)
    min_df["Date"] = min_df.apply(lambda row: get_date1(row["Date"]), axis=1)
    cutoff_date = datetime(year=2007, month=1, day=1)
    rep_df = maj_df[maj_df.Date > cutoff_date]
    dem_df = min_df[min_df.Date > cutoff_date]
    committee = committee.upper()
    rep_df["Party"] = "Republican"
    rep_df["Committee"] = committee
    rep_df["Label"] = "Republican, " + committee
    dem_df["Party"] = "Democratic"
    dem_df["Committee"] = committee
    dem_df["Label"] = "Democratic, " + committee
    dem_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/democratic.pkl".format(committee)
    with open(dem_file, "wb") as picklefile:
        pickle.dump(dem_df, picklefile)
    rep_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/republican.pkl".format(committee)
    with open(rep_file, "wb") as picklefile:
        pickle.dump(rep_df, picklefile)
    return rep_df

# %%
def adjust_df7(group, committee, party):
    print(1, committee)
    committee = committee.lower().replace(" ", "_")
    print(2, committee)
    party = party.lower()
    group = group.lower()
    file_path = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee, group)
    df = pd.read_pickle(file_path)
    df = df[df["Date"]!= ""]
    df["Date"] = df.apply(lambda row: get_date2(row["Date"]), axis=1) 
    df["Year"] = df.apply(lambda row: get_year(row["Date"]), axis=1)
    df["Month"] = df.apply(lambda row: get_month(row["Date"]), axis=1)
    df["Day"] = df.apply(lambda row: get_day(row["Date"]), axis=1)
    df["Party"] = party.title()
    committee = committee.replace("_", " ").title()
    print(3, committee)
    df["Committee"] = committee
    df["Label"] = party.title() + ", " + committee
    
    dest_file = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/{}/{}.pkl".format(committee.replace(" ", "_").lower(), party)
    print(dest_file)
    with open(dest_file, "wb") as picklefile:
        pickle.dump(df, picklefile)
    return df

# %%
#Appropriations
apr_maj_df = adjust_df1("majority", "appropriations", "republican")
apr_min_df = adjust_df1("minority", "appropriations", "Democratic")

# %%
#bank_gop_temp = bank_gop
bank_gop = adjust_df2("republican", "banking")
# Out:
# /Users/danielgilberg/data_science/metis/nlp_partisanship/data/banking/republican.pkl

# %%
budget_maj_df = adjust_df1("chairman", "budget", "republican")
budget_min_df = adjust_df1("ranking-member", "budget", "democratic")

# %%
commerce_dem_df = adjust_df3("democratic", "commerce")
commerce_gop_df = adjust_df3("republican", "commerce")

# %%
adjust_df4("finance")
# Out:
#           Date                                              Title  \
# 0   2017-11-22  Senate Tax Bill Levels the Playing Field for A...
# 1   2017-11-21  The Senate Tax Proposal Delivers Benefits Dire...
# 2   2017-11-20  Regular Order: 23.5 Hours Over Four Days, 350+...
# 3   2017-11-18  Real World Impact: Typical Family Saves Nearly...
# 4   2017-11-17  Making History, Finance Committee Clears Compr...
# 5   2017-11-17  Repealing the Individual Mandate Tax Will Bene...
# 6   2017-11-16     Finance Committee Passes Historic Tax Overhaul
# 7   2017-11-16  A Tax Plan to Provide Relief for the Middle-Class
# 8   2017-11-16  Hatch Remarks at Finance Committee Markup of T...
# 9   2017-11-16  Senate Tax Plan Designed To Lift American Fami...
# 10  2017-11-15  The Obamacare Individual Mandate Tax is Failin...
# 11  2017-11-15  Hatch Remarks at Finance Committee Markup of T...
# 12  2017-11-15                      NFIB Endorses Senate Tax Bill
# ...

# %%
adjust_df5("Foreign Relations")
# Out:
# /Users/danielgilberg/data_science/metis/nlp_partisanship/data/foreign_relations/chairman.pkl
#           Date                                              Title  \
# 0   2017-11-14  Corker, Coons Bill to Improve Accountability a...
# 1   2017-11-14  Corker Statement at Hearing on Authority to Or...
# 2   2017-10-30  Corker Statement at Hearing on Authorizations ...
# 3   2017-10-26  Corker Statement on Implementation of Sanction...
# 4   2017-10-19  Corker Statement at Hearing on Modernizing Foo...
# 5   2017-10-13  Corker Statement on Legislative Strategy to Ad...
# 6   2017-10-05  Corker, Coons Introduce Bill to Improve Accoun...
# 7   2017-10-03  Corker Statement at Hearing on Nomination for ...
# 8   2017-09-21  Corker Applauds President Trump’s Executive Or...
# 9   2017-09-20  Corker Statement on Trump Address to United Na...
# 10  2017-09-19  Corker Statement at Nomination Hearing for US ...
# 11  2017-09-19  Corker: UK Matches $25 Million US Investment i...
# ...

# %%
adjust_df6("HELP")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
adjust_df7("majority", "small business", "republican")
# Out:
# 1 small business
# 2 small_business
# 3 Small Business
# /Users/danielgilberg/data_science/metis/nlp_partisanship/data/small_business/republican.pkl
#           Date                                              Title  \
# 0   2017-11-21  Risch Recognizes Aberdeen Business as Small Bu...
# 1   2017-11-14  Risch Speaks on Senate Floor about Growing Sma...
# 2   2017-11-13  Senate Passes Risch, Shaheen Bipartisan Resolu...
# 3   2017-11-02       Risch Statement on House Tax Reform Proposal
# 4   2017-10-31  Risch Recognizes Veteran-Owned Idaho Falls Bus...
# 5   2017-10-31  Senate Passes Risch, Shaheen Bipartisan Resolu...
# 6   2017-10-30  Chairman Risch Cites Tax Burden as Significant...
# 7   2017-10-24  Risch Applauds Idaho's A+ Rating in Small Busi...
# 8   2017-09-29  Risch Honors Eagle Software Company as Septemb...
# 9   2017-09-28  Senate Passes Risch-Schatz Small Business Cybe...
# 10  2017-09-28  Risch Holds Hearing on SBA's Hurricane Respons...
# ...

# %% [markdown]
# #### Aggregating

# %%
def combine_dfs():
    folder = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data"
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir() ] 
    final = list()
    for folder in subfolders:
        dem_str = folder + "/democratic.pkl"
        rep_str = folder + "/republican.pkl"
        try:
            df = pd.read_pickle(dem_str)
            final.append(df)
            df = pd.read_pickle(rep_str)
            final.append(df)
        except:
            final=final
            
    final_df = pd.concat(final).reset_index().drop("index", axis=1)
    file_path = "/Users/danielgilberg/data_science/metis/nlp_partisanship/data/all_committees.pkl"
    with open(file_path, "wb") as picklefile:
        pickle.dump(final_df, picklefile)
    return final_df

test = combine_dfs()

# %%
# Out:
#             Committee       Date   Day                       Label  Month  \
# 0         Agriculture 2017-11-09   9.0     Democratic, Agriculture   11.0
# 1         Agriculture 2017-11-02   2.0     Democratic, Agriculture   11.0
# 2         Agriculture 2017-11-01   1.0     Democratic, Agriculture   11.0
# 3         Agriculture 2017-10-18  18.0     Democratic, Agriculture   10.0
# 4         Agriculture 2017-10-17  17.0     Democratic, Agriculture   10.0
# 5         Agriculture 2017-10-05   5.0     Democratic, Agriculture   10.0
# 6         Agriculture 2017-09-28  28.0     Democratic, Agriculture    9.0
# 7         Agriculture 2017-09-19  19.0     Democratic, Agriculture    9.0
# 8         Agriculture 2017-09-14  14.0     Democratic, Agriculture    9.0
# 9         Agriculture 2017-08-31  31.0     Democratic, Agriculture    8.0
# 10        Agriculture 2017-08-25  25.0     Democratic, Agriculture    8.0
# 11        Agriculture 2017-08-08   8.0     Democratic, Agriculture    8.0
# ...
